# %%
# ============================================================
# KoVAE Real vs Synthetic: Realism + Diversity Evaluation
# One-cell notebook version
# No saving by default
# ============================================================

from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# ============================================================
# Project paths
# ============================================================

PROJECT_ROOT = Path("/home/iailab42/khans1/projects")

REAL_DIR = PROJECT_ROOT / "data"
SYN_DIR = PROJECT_ROOT / "data" / "synthetic"

REAL_X_PATH = REAL_DIR / "all_X.npy"
REAL_Y_PATH = REAL_DIR / "all_y.npy"
REAL_SUBJECT_PATH = REAL_DIR / "all_subject.npy"
REAL_METADATA_PATH = REAL_DIR / "all_metadata.csv"

SYN_X_PATH = SYN_DIR / "all_X_synthetic.npy"
SYN_Y_PATH = SYN_DIR / "all_y_synthetic.npy"
SYN_SUBJECT_PATH = SYN_DIR / "all_subject_synthetic.npy"
SYN_METADATA_PATH = SYN_DIR / "all_metadata_synthetic.csv"

# OUT_DIR = PROJECT_ROOT / "results" / "realism_diversity"
# OUT_DIR.mkdir(parents=True, exist_ok=True)


# ============================================================
# Constants
# ============================================================

TARGET_HZ = 64
WINDOW_LEN = 512
SHIFT_LEN = 128

CHANNEL_NAMES = ["ACC_x", "ACC_y", "ACC_z", "BVP", "EDA", "TEMP"]
NUM_CHANNELS = len(CHANNEL_NAMES)

ACTIVITY_IDS = [1, 2, 3, 4, 5, 6, 7, 8]

REAL_SUBJECT_TO_PLOT = "S1"
SYN_SUBJECT_TO_PLOT = "SYN_001"

MAX_REAL_WINDOWS_PER_ACTIVITY_FOR_DIVERSITY = 1000
MAX_SYN_WINDOWS_PER_ACTIVITY_FOR_DIVERSITY = 1000
DISTANCE_BATCH_SIZE = 256

RANDOM_SEED = 42


# ============================================================
# Basic helpers
# ============================================================

def require_file(path):
    path = Path(path)
    if not path.exists():
        raise FileNotFoundError(f"Missing file: {path}")
    return path


def check_window_shape(X, expected_channels, name):
    if X.ndim != 3:
        raise ValueError(f"{name}: expected [N, T, C], got {X.shape}")
    if X.shape[1] != WINDOW_LEN:
        raise ValueError(f"{name}: expected window length {WINDOW_LEN}, got {X.shape[1]}")
    if X.shape[2] != expected_channels:
        raise ValueError(f"{name}: expected {expected_channels} channels, got {X.shape[2]}")


def safe_mean(x):
    return float(np.mean(x)) if len(x) else np.nan


def safe_std(x):
    return float(np.std(x)) if len(x) else np.nan


def histogram_overlap(real_values, syn_values, bins=80):
    real_values = np.asarray(real_values, dtype=np.float32).reshape(-1)
    syn_values = np.asarray(syn_values, dtype=np.float32).reshape(-1)

    real_values = real_values[np.isfinite(real_values)]
    syn_values = syn_values[np.isfinite(syn_values)]

    if len(real_values) == 0 or len(syn_values) == 0:
        return np.nan

    vmin = float(min(real_values.min(), syn_values.min()))
    vmax = float(max(real_values.max(), syn_values.max()))

    if vmin == vmax:
        return 1.0

    hist_real, bin_edges = np.histogram(real_values, bins=bins, range=(vmin, vmax))
    hist_syn, _ = np.histogram(syn_values, bins=bin_edges)

    hist_real = hist_real.astype(np.float64)
    hist_syn = hist_syn.astype(np.float64)

    hist_real /= hist_real.sum()
    hist_syn /= hist_syn.sum()

    return float(np.minimum(hist_real, hist_syn).sum())


def ks_statistic_sampled(real_values, syn_values, max_points=100000, seed=42):
    rng = np.random.default_rng(seed)

    real_values = np.asarray(real_values, dtype=np.float32).reshape(-1)
    syn_values = np.asarray(syn_values, dtype=np.float32).reshape(-1)

    real_values = real_values[np.isfinite(real_values)]
    syn_values = syn_values[np.isfinite(syn_values)]

    if len(real_values) == 0 or len(syn_values) == 0:
        return np.nan

    if len(real_values) > max_points:
        real_values = real_values[rng.choice(len(real_values), size=max_points, replace=False)]

    if len(syn_values) > max_points:
        syn_values = syn_values[rng.choice(len(syn_values), size=max_points, replace=False)]

    real_sorted = np.sort(real_values)
    syn_sorted = np.sort(syn_values)
    all_values = np.sort(np.concatenate([real_sorted, syn_sorted]))

    real_cdf = np.searchsorted(real_sorted, all_values, side="right") / len(real_sorted)
    syn_cdf = np.searchsorted(syn_sorted, all_values, side="right") / len(syn_sorted)

    return float(np.max(np.abs(real_cdf - syn_cdf)))


def average_log_fft(windows, channel_idx):
    if len(windows) == 0:
        return None

    sig = windows[:, :, channel_idx]
    fft = np.fft.rfft(sig, axis=1)
    mag = np.log1p(np.abs(fft))
    return mag.mean(axis=0).astype(np.float32)


def fft_mae_and_corr(real_windows, syn_windows, channel_idx):
    real_fft = average_log_fft(real_windows, channel_idx)
    syn_fft = average_log_fft(syn_windows, channel_idx)

    if real_fft is None or syn_fft is None:
        return np.nan, np.nan

    mae = float(np.mean(np.abs(real_fft - syn_fft)))

    if np.std(real_fft) < 1e-8 or np.std(syn_fft) < 1e-8:
        corr = np.nan
    else:
        corr = float(np.corrcoef(real_fft, syn_fft)[0, 1])

    return mae, corr


# ============================================================
# Load data
# ============================================================

def load_real_data():
    require_file(REAL_X_PATH)
    require_file(REAL_Y_PATH)
    require_file(REAL_SUBJECT_PATH)
    require_file(REAL_METADATA_PATH)

    X = np.load(REAL_X_PATH).astype(np.float32)
    y = np.load(REAL_Y_PATH).astype(np.int64)
    subjects = np.load(REAL_SUBJECT_PATH, allow_pickle=True).astype(str)
    metadata = pd.read_csv(REAL_METADATA_PATH)

    check_window_shape(X, NUM_CHANNELS, "Real X")

    metadata = metadata.copy()
    metadata["subject"] = subjects
    metadata["activity_label"] = y
    metadata["array_index"] = np.arange(len(y), dtype=np.int64)

    return X, y, subjects, metadata


def load_synthetic_data():
    require_file(SYN_X_PATH)
    require_file(SYN_Y_PATH)
    require_file(SYN_SUBJECT_PATH)
    require_file(SYN_METADATA_PATH)

    X = np.load(SYN_X_PATH).astype(np.float32)
    y = np.load(SYN_Y_PATH).astype(np.int64)
    subjects = np.load(SYN_SUBJECT_PATH, allow_pickle=True).astype(str)
    metadata = pd.read_csv(SYN_METADATA_PATH)

    check_window_shape(X, NUM_CHANNELS, "Synthetic X")

    metadata = metadata.copy()
    metadata["synthetic_subject"] = subjects
    metadata["activity_label"] = y
    metadata["array_index"] = np.arange(len(y), dtype=np.int64)

    return X, y, subjects, metadata


real_X, real_y, real_subjects, real_meta = load_real_data()
syn_X, syn_y, syn_subjects, syn_meta = load_synthetic_data()

print("Real X:", real_X.shape)
print("Synthetic X:", syn_X.shape)
print("\nReal label counts:", dict(zip(*np.unique(real_y, return_counts=True))))
print("Synthetic label counts:", dict(zip(*np.unique(syn_y, return_counts=True))))
print("\nSynthetic subjects:", sorted(np.unique(syn_subjects).tolist())[:20])


# ============================================================
# Realism metrics
# ============================================================

def compute_realism_metrics(real_X, real_y, syn_X, syn_y):
    rows = []

    for act in ACTIVITY_IDS:
        real_act = real_X[real_y == act]
        syn_act = syn_X[syn_y == act]

        print(f"Realism | Activity {act}: real={real_act.shape}, synthetic={syn_act.shape}")

        if len(real_act) == 0 or len(syn_act) == 0:
            continue

        for c, channel_name in enumerate(CHANNEL_NAMES):
            real_values = real_act[:, :, c].reshape(-1)
            syn_values = syn_act[:, :, c].reshape(-1)

            real_diff = np.diff(real_act[:, :, c], axis=1).reshape(-1)
            syn_diff = np.diff(syn_act[:, :, c], axis=1).reshape(-1)

            real_abs_diff = np.abs(real_diff)
            syn_abs_diff = np.abs(syn_diff)

            spike_threshold = np.percentile(real_abs_diff, 99.0)

            fft_mae, fft_corr = fft_mae_and_corr(real_act, syn_act, c)

            rows.append({
                "activity": act,
                "channel": channel_name,
                "real_num_windows": int(len(real_act)),
                "syn_num_windows": int(len(syn_act)),
                "real_mean": safe_mean(real_values),
                "syn_mean": safe_mean(syn_values),
                "abs_mean_diff": abs(safe_mean(real_values) - safe_mean(syn_values)),
                "real_std": safe_std(real_values),
                "syn_std": safe_std(syn_values),
                "abs_std_diff": abs(safe_std(real_values) - safe_std(syn_values)),
                "histogram_overlap_higher_better": histogram_overlap(real_values, syn_values),
                "ks_statistic_lower_better": ks_statistic_sampled(
                    real_values,
                    syn_values,
                    seed=RANDOM_SEED + act + c,
                ),
                "real_abs_derivative_mean": safe_mean(real_abs_diff),
                "syn_abs_derivative_mean": safe_mean(syn_abs_diff),
                "abs_derivative_mean_diff": abs(safe_mean(real_abs_diff) - safe_mean(syn_abs_diff)),
                "real_spike_rate_real_99pct_threshold": float(np.mean(real_abs_diff > spike_threshold)),
                "syn_spike_rate_real_99pct_threshold": float(np.mean(syn_abs_diff > spike_threshold)),
                "fft_logmag_mae_lower_better": fft_mae,
                "fft_logmag_corr_higher_better": fft_corr,
            })

    return pd.DataFrame(rows)


realism_df = compute_realism_metrics(real_X, real_y, syn_X, syn_y)

print("\nRealism metrics preview:")
display(realism_df.head(12))

realism_by_channel = (
    realism_df
    .groupby("channel", as_index=False)
    .mean(numeric_only=True)
)

print("\nAverage realism by channel:")
display(realism_by_channel)


# realism_df.to_csv(OUT_DIR / "realism_metrics_by_activity_channel.csv", index=False)
# realism_by_channel.to_csv(OUT_DIR / "realism_average_by_channel.csv", index=False)


# ============================================================
# Histogram + FFT plots for selected activities
# ============================================================

def plot_hist_fft_for_activity(act):
    real_act = real_X[real_y == act]
    syn_act = syn_X[syn_y == act]

    if len(real_act) == 0 or len(syn_act) == 0:
        print("Missing real or synthetic windows for activity", act)
        return

    fig, axes = plt.subplots(
        nrows=NUM_CHANNELS,
        ncols=2,
        figsize=(16, 3.0 * NUM_CHANNELS),
    )

    for c, channel_name in enumerate(CHANNEL_NAMES):
        real_values = real_act[:, :, c].reshape(-1)
        syn_values = syn_act[:, :, c].reshape(-1)

        ax = axes[c, 0]
        vmin = min(float(real_values.min()), float(syn_values.min()))
        vmax = max(float(real_values.max()), float(syn_values.max()))

        if vmin == vmax:
            vmin -= 1.0
            vmax += 1.0

        bins = np.linspace(vmin, vmax, 80)

        ax.hist(real_values, bins=bins, density=True, alpha=0.45, label="Real")
        ax.hist(syn_values, bins=bins, density=True, alpha=0.45, label="Synthetic")
        ax.set_title(f"Activity {act} | {channel_name} distribution")
        ax.set_xlabel("Normalized value")
        ax.set_ylabel("Density")
        ax.legend()

        ax = axes[c, 1]
        real_fft = average_log_fft(real_act, c)
        syn_fft = average_log_fft(syn_act, c)
        freqs = np.fft.rfftfreq(WINDOW_LEN, d=1.0 / TARGET_HZ)

        ax.plot(freqs, real_fft, linewidth=1.0, label="Real")
        ax.plot(freqs, syn_fft, linewidth=1.0, label="Synthetic")
        ax.set_title(f"Activity {act} | {channel_name} average log FFT")
        ax.set_xlabel("Frequency (Hz)")
        ax.set_ylabel("log(1 + magnitude)")
        ax.legend()

    plt.tight_layout()
    # plt.savefig(OUT_DIR / f"hist_fft_activity_{act}.png", dpi=150)
    plt.show()


for act in [1, 5, 8]:
    plot_hist_fft_for_activity(act)


# ============================================================
# Diversity metrics
# ============================================================

def sample_windows_for_activity(X, y, activity_id, max_windows, rng):
    idx = np.where(y == int(activity_id))[0]

    if len(idx) == 0:
        return np.empty((0, WINDOW_LEN, NUM_CHANNELS), dtype=np.float32)

    if len(idx) > max_windows:
        idx = rng.choice(idx, size=max_windows, replace=False)

    return X[idx].astype(np.float32)


def flatten_channel_windows(windows, channel_idx):
    if len(windows) == 0:
        return np.empty((0, WINDOW_LEN), dtype=np.float32)
    return windows[:, :, channel_idx].reshape(len(windows), WINDOW_LEN)


def nearest_mse_distances(A, B, batch_size=256, exclude_self=False):
    A = np.asarray(A, dtype=np.float32)
    B = np.asarray(B, dtype=np.float32)

    if len(A) == 0 or len(B) == 0:
        return np.array([], dtype=np.float32)

    if exclude_self and len(A) != len(B):
        raise ValueError("exclude_self=True requires A and B to have same length.")

    D = A.shape[1]
    B_T = B.T
    B_norm = np.sum(B * B, axis=1)[None, :]

    nearest = []

    for start in range(0, len(A), batch_size):
        end = min(start + batch_size, len(A))
        A_batch = A[start:end]
        A_norm = np.sum(A_batch * A_batch, axis=1)[:, None]

        dist = (A_norm + B_norm - 2.0 * (A_batch @ B_T)) / float(D)
        dist = np.maximum(dist, 0.0)

        if exclude_self:
            rows = np.arange(end - start)
            cols = np.arange(start, end)
            dist[rows, cols] = np.inf

        nearest.append(np.min(dist, axis=1).astype(np.float32))

    return np.concatenate(nearest, axis=0)


def summarize_dist(values, prefix):
    values = np.asarray(values, dtype=np.float32)
    values = values[np.isfinite(values)]

    if len(values) == 0:
        return {
            f"{prefix}_mean": np.nan,
            f"{prefix}_median": np.nan,
            f"{prefix}_p05": np.nan,
            f"{prefix}_p95": np.nan,
        }

    return {
        f"{prefix}_mean": float(np.mean(values)),
        f"{prefix}_median": float(np.median(values)),
        f"{prefix}_p05": float(np.percentile(values, 5)),
        f"{prefix}_p95": float(np.percentile(values, 95)),
    }


def compute_diversity_metrics(real_X, real_y, syn_X, syn_y):
    rng = np.random.default_rng(RANDOM_SEED)
    rows = []

    for act in ACTIVITY_IDS:
        real_sample = sample_windows_for_activity(
            real_X,
            real_y,
            act,
            MAX_REAL_WINDOWS_PER_ACTIVITY_FOR_DIVERSITY,
            rng,
        )

        syn_sample = sample_windows_for_activity(
            syn_X,
            syn_y,
            act,
            MAX_SYN_WINDOWS_PER_ACTIVITY_FOR_DIVERSITY,
            rng,
        )

        print(f"Diversity | Activity {act}: real={real_sample.shape}, synthetic={syn_sample.shape}")

        if len(real_sample) == 0 or len(syn_sample) == 0:
            continue

        for c, channel_name in enumerate(CHANNEL_NAMES):
            real_flat = flatten_channel_windows(real_sample, c)
            syn_flat = flatten_channel_windows(syn_sample, c)

            syn_to_real = nearest_mse_distances(
                syn_flat,
                real_flat,
                batch_size=DISTANCE_BATCH_SIZE,
                exclude_self=False,
            )

            syn_to_syn = nearest_mse_distances(
                syn_flat,
                syn_flat,
                batch_size=DISTANCE_BATCH_SIZE,
                exclude_self=True,
            )

            real_to_real = nearest_mse_distances(
                real_flat,
                real_flat,
                batch_size=DISTANCE_BATCH_SIZE,
                exclude_self=True,
            )

            row = {
                "activity": act,
                "channel": channel_name,
                "real_sampled_windows": int(len(real_sample)),
                "synthetic_sampled_windows": int(len(syn_sample)),
            }

            row.update(summarize_dist(real_to_real, "real_to_nearest_real_mse"))
            row.update(summarize_dist(syn_to_syn, "syn_to_nearest_syn_mse"))
            row.update(summarize_dist(syn_to_real, "syn_to_nearest_real_mse"))

            real_ref = row["real_to_nearest_real_mse_mean"]
            syn_ref = row["syn_to_nearest_syn_mse_mean"]
            syn_real_ref = row["syn_to_nearest_real_mse_mean"]

            row["syn_nn_vs_real_nn_ratio"] = (
                syn_ref / real_ref if np.isfinite(real_ref) and real_ref > 1e-12 else np.nan
            )

            row["syn_nearest_real_vs_real_nn_ratio"] = (
                syn_real_ref / real_ref if np.isfinite(real_ref) and real_ref > 1e-12 else np.nan
            )

            rows.append(row)

    return pd.DataFrame(rows)


diversity_df = compute_diversity_metrics(real_X, real_y, syn_X, syn_y)

print("\nDiversity metrics preview:")
display(diversity_df.head(12))

diversity_by_channel = (
    diversity_df
    .groupby("channel", as_index=False)
    .mean(numeric_only=True)
)

diversity_by_activity = (
    diversity_df
    .groupby("activity", as_index=False)
    .mean(numeric_only=True)
)

print("\nAverage diversity by channel:")
display(diversity_by_channel)

print("\nAverage diversity by activity:")
display(diversity_by_activity)


# diversity_df.to_csv(OUT_DIR / "diversity_metrics_by_activity_channel.csv", index=False)
# diversity_by_channel.to_csv(OUT_DIR / "diversity_average_by_channel.csv", index=False)
# diversity_by_activity.to_csv(OUT_DIR / "diversity_average_by_activity.csv", index=False)


# ============================================================
# Diversity summary plots
# ============================================================

def plot_diversity_summary_by_channel(diversity_df):
    avg = (
        diversity_df
        .groupby("channel", as_index=False)[
            [
                "real_to_nearest_real_mse_mean",
                "syn_to_nearest_syn_mse_mean",
                "syn_to_nearest_real_mse_mean",
            ]
        ]
        .mean()
    )

    x = avg["channel"].astype(str).to_numpy()
    pos = np.arange(len(x))
    width = 0.25

    fig, ax = plt.subplots(figsize=(12, 6))
    ax.bar(pos - width, avg["real_to_nearest_real_mse_mean"], width, label="Real → nearest real")
    ax.bar(pos, avg["syn_to_nearest_syn_mse_mean"], width, label="Synthetic → nearest synthetic")
    ax.bar(pos + width, avg["syn_to_nearest_real_mse_mean"], width, label="Synthetic → nearest real")

    ax.set_xticks(pos)
    ax.set_xticklabels(x)
    ax.set_xlabel("Channel")
    ax.set_ylabel("Nearest-window MSE")
    ax.set_title("Diversity comparison by channel")
    ax.legend()

    plt.tight_layout()
    # plt.savefig(OUT_DIR / "diversity_summary_by_channel.png", dpi=150)
    plt.show()


def plot_diversity_summary_by_activity(diversity_df):
    avg = (
        diversity_df
        .groupby("activity", as_index=False)[
            [
                "real_to_nearest_real_mse_mean",
                "syn_to_nearest_syn_mse_mean",
                "syn_to_nearest_real_mse_mean",
            ]
        ]
        .mean()
    )

    x = avg["activity"].astype(str).to_numpy()
    pos = np.arange(len(x))
    width = 0.25

    fig, ax = plt.subplots(figsize=(12, 6))
    ax.bar(pos - width, avg["real_to_nearest_real_mse_mean"], width, label="Real → nearest real")
    ax.bar(pos, avg["syn_to_nearest_syn_mse_mean"], width, label="Synthetic → nearest synthetic")
    ax.bar(pos + width, avg["syn_to_nearest_real_mse_mean"], width, label="Synthetic → nearest real")

    ax.set_xticks(pos)
    ax.set_xticklabels(x)
    ax.set_xlabel("Activity")
    ax.set_ylabel("Nearest-window MSE")
    ax.set_title("Diversity comparison by activity")
    ax.legend()

    plt.tight_layout()
    # plt.savefig(OUT_DIR / "diversity_summary_by_activity.png", dpi=150)
    plt.show()


plot_diversity_summary_by_channel(diversity_df)
plot_diversity_summary_by_activity(diversity_df)

print("\nDone.")
# Out:
# Real X: (46907, 512, 6)
# Synthetic X: (8000, 512, 6)
#
# Real label counts: {np.int64(1): np.int64(4534), np.int64(2): np.int64(3205), np.int64(3): np.int64(2277), np.int64(4): np.int64(3439), np.int64(5): np.int64(6807), np.int64(6): np.int64(13518), np.int64(7): np.int64(4660), np.int64(8): np.int64(8467)}
# Synthetic label counts: {np.int64(1): np.int64(1000), np.int64(2): np.int64(1000), np.int64(3): np.int64(1000), np.int64(4): np.int64(1000), np.int64(5): np.int64(1000), np.int64(6): np.int64(1000), np.int64(7): np.int64(1000), np.int64(8): np.int64(1000)}
#
# Synthetic subjects: ['SYN_001', 'SYN_002', 'SYN_003', 'SYN_004', 'SYN_005', 'SYN_006', 'SYN_007', 'SYN_008', 'SYN_009', 'SYN_010']
# Realism | Activity 1: real=(4534, 512, 6), synthetic=(1000, 512, 6)
# Realism | Activity 2: real=(3205, 512, 6), synthetic=(1000, 512, 6)
# Realism | Activity 3: real=(2277, 512, 6), synthetic=(1000, 512, 6)
# Realism | Activity 4: real=(3439, 512, 6), synthetic=(1000, 512, 6)
# Realism | Activity 5: real=(6807, 512, 6), synthetic=(1000, 512, 6)
# Realism | Activity 6: real=(13518, 512, 6), synthetic=(1000, 512, 6)
# Realism | Activity 7: real=(4660, 512, 6), synthetic=(1000, 512, 6)
# Realism | Activity 8: real=(8467, 512, 6), synthetic=(1000, 512, 6)
#
# Realism metrics preview:
#     activity channel  real_num_windows  syn_num_windows  real_mean  syn_mean  \
# 0          1   ACC_x              4534             1000  -0.587700 -0.742953
# 1          1   ACC_y              4534             1000  -0.097927 -0.212385
# 2          1   ACC_z              4534             1000  -0.116179 -0.342989
# 3          1     BVP              4534             1000   0.000034  0.016706
# 4          1     EDA              4534             1000  -0.650187 -0.742554
# 5          1    TEMP              4534             1000  -1.143305 -1.080314
# 6          2   ACC_x              3205             1000   0.534497  0.435986
# 7          2   ACC_y              3205             1000   1.073466  0.960955
# 8          2   ACC_z              3205             1000  -0.560416 -0.829773
# 9          2     BVP              3205             1000   0.000068  0.010089
# 10         2     EDA              3205             1000  -0.215347 -0.291072
# 11         2    TEMP              3205             1000  -1.197171 -1.158810
#
#     abs_mean_diff  real_std   syn_std  abs_std_diff  \
# 0        0.155252  0.747102  0.597367      0.149735
# 1        0.114459  0.556064  0.409266      0.146798
# 2        0.226809  1.002626  0.711924      0.290702
# 3        0.016672  0.529769  0.553363      0.023594
# 4        0.092366  0.378101  0.176356      0.201744
# 5        0.062990  0.146237  0.085788      0.060448
# 6        0.098511  0.735058  0.802003      0.066945
# 7        0.112511  1.248466  0.898781      0.349685
# 8        0.269357  0.613196  0.697283      0.084088
# 9        0.010022  0.887073  0.925797      0.038723
# 10       0.075724  0.959968  0.597378      0.362590
# 11       0.038360  0.167598  0.082791      0.084807
#
#     histogram_overlap_higher_better  ks_statistic_lower_better  \
# 0                          0.564673                    0.21764
# 1                          0.590808                    0.33714
# 2                          0.593418                    0.30233
# 3                          0.955874                    0.04088
# 4                          0.278722                    0.31024
# 5                          0.545453                    0.32709
# 6                          0.850646                    0.13516
# 7                          0.690030                    0.21704
# 8                          0.769918                    0.23556
# 9                          0.933476                    0.03841
# 10                         0.378299                    0.38479
# 11                         0.439686                    0.37895
#
#     real_abs_derivative_mean  syn_abs_derivative_mean  \
# 0                   0.011643                 0.029200
# 1                   0.003986                 0.010153
# 2                   0.009624                 0.025429
# 3                   0.045975                 0.068040
# 4                   0.000036                 0.002338
# 5                   0.000029                 0.002365
# 6                   0.112475                 0.182569
# 7                   0.098349                 0.157007
# 8                   0.078909                 0.144113
# 9                   0.092809                 0.140700
# 10                  0.000351                 0.006170
# 11                  0.000030                 0.005013
#
#     abs_derivative_mean_diff  real_spike_rate_real_99pct_threshold  \
# 0                   0.017556                              0.009439
# 1                   0.006167                              0.009407
# 2                   0.015805                              0.009535
# 3                   0.022065                              0.010000
# 4                   0.002303                              0.009527
# 5                   0.002336                              0.007252
# 6                   0.070094                              0.009859
# 7                   0.058658                              0.009972
# 8                   0.065204                              0.009862
# 9                   0.047891                              0.010000
# 10                  0.005819                              0.009977
# 11                  0.004983                              0.007502
#
#     syn_spike_rate_real_99pct_threshold  fft_logmag_mae_lower_better  \
# 0                              0.012137                     0.274149
# 1                              0.016170                     0.189286
# 2                              0.012466                     0.278882
# 3                              0.010814                     0.327788
# 4                              0.886104                     0.085735
# 5                              0.890853                     0.077966
# 6                              0.015519                     0.347063
# 7                              0.027665                     0.347852
# 8                              0.019526                     0.383219
# 9                              0.014926                     0.493750
# 10                             0.622378                     0.138604
# 11                             0.945840                     0.139760
#
#     fft_logmag_corr_higher_better
# 0                        0.968059
# 1                        0.947041
# 2                        0.943486
# 3                        0.994021
# 4                        0.986581
# 5                        0.994866
# 6                        0.998236
# 7                        0.998209
# 8                        0.997824
# 9                        0.990314
# 10                       0.965078
# 11                       0.991684
# Average realism by channel:
#   channel  activity  real_num_windows  syn_num_windows  real_mean  syn_mean  \
# 0   ACC_x       4.5          5863.375           1000.0   0.084278 -0.126592
# 1   ACC_y       4.5          5863.375           1000.0   0.259230  0.229662
# 2   ACC_z       4.5          5863.375           1000.0  -0.076229 -0.279359
# 3     BVP       4.5          5863.375           1000.0   0.000027  0.019371
# 4     EDA       4.5          5863.375           1000.0   0.123278  0.173386
# 5    TEMP       4.5          5863.375           1000.0  -1.040602 -1.018508
#
#    abs_mean_diff  real_std   syn_std  abs_std_diff  \
# 0       0.210869  0.930833  0.873115      0.081642
# 1       0.106310  0.846596  0.648421      0.198175
# 2       0.203130  0.866439  0.820063      0.083131
# 3       0.019344  1.027465  1.054352      0.030859
# 4       0.092130  0.832576  0.467868      0.364708
# 5       0.045272  0.201748  0.125542      0.076206
#
#    histogram_overlap_higher_better  ks_statistic_lower_better  \
# 0                         0.797984                   0.160560
# 1                         0.695528                   0.216172
# 2                         0.760198                   0.207496
# 3                         0.957127                   0.035194
# 4                         0.548102                   0.299441
# 5                         0.621360                   0.260983
#
#    real_abs_derivative_mean  syn_abs_derivative_mean  \
# 0                  0.146369                 0.189465
# 1                  0.078397                 0.108904
# 2                  0.101998                 0.145285
# 3                  0.100422                 0.138178
# 4                  0.000486                 0.006287
# 5                  0.000029                 0.004747
#
#    abs_derivative_mean_diff  real_spike_rate_real_99pct_threshold  \
# 0                  0.043096                              0.009803
# 1                  0.030507                              0.009851
# 2                  0.043288                              0.009809
# 3                  0.037757                              0.009998
# 4                  0.005801                              0.009927
# 5                  0.004718                              0.008701
#
#    syn_spike_rate_real_99pct_threshold  fft_logmag_mae_lower_better  \
# 0                             0.012340                     0.240462
# 1                             0.018276                     0.245110
# 2                             0.013711                     0.274195
# 3                             0.014347                     0.386441
# 4                             0.588309                     0.131468
# 5                             0.929693                     0.137396
#
#    fft_logmag_corr_higher_better
# 0                       0.993960
# 1                       0.987333
# 2                       0.988827
# 3                       0.995020
# 4                       0.981110
# 5                       0.987669
# Diversity | Activity 1: real=(1000, 512, 6), synthetic=(1000, 512, 6)
# Diversity | Activity 2: real=(1000, 512, 6), synthetic=(1000, 512, 6)
# Diversity | Activity 3: real=(1000, 512, 6), synthetic=(1000, 512, 6)
# Diversity | Activity 4: real=(1000, 512, 6), synthetic=(1000, 512, 6)
# Diversity | Activity 5: real=(1000, 512, 6), synthetic=(1000, 512, 6)
# Diversity | Activity 6: real=(1000, 512, 6), synthetic=(1000, 512, 6)
# Diversity | Activity 7: real=(1000, 512, 6), synthetic=(1000, 512, 6)
# Diversity | Activity 8: real=(1000, 512, 6), synthetic=(1000, 512, 6)
#
# Diversity metrics preview:
#     activity channel  real_sampled_windows  synthetic_sampled_windows  \
# 0          1   ACC_x                  1000                       1000
# 1          1   ACC_y                  1000                       1000
# 2          1   ACC_z                  1000                       1000
# 3          1     BVP                  1000                       1000
# 4          1     EDA                  1000                       1000
# 5          1    TEMP                  1000                       1000
# 6          2   ACC_x                  1000                       1000
# 7          2   ACC_y                  1000                       1000
# 8          2   ACC_z                  1000                       1000
# 9          2     BVP                  1000                       1000
# 10         2     EDA                  1000                       1000
# 11         2    TEMP                  1000                       1000
#
#     real_to_nearest_real_mse_mean  real_to_nearest_real_mse_median  \
# 0                        0.024811                         0.000559
# 1                        0.007776                         0.000127
# 2                        0.033520                         0.000469
# 3                        0.143852                         0.050200
# 4                        0.000030                         0.000000
# 5                        0.000004                         0.000003
# 6                        0.379460                         0.251776
# 7                        0.296835                         0.250726
# 8                        0.246694                         0.150087
# 9                        0.613785                         0.246191
# 10                       0.001272                         0.000011
# 11                       0.000004                         0.000003
#
#     real_to_nearest_real_mse_p05  real_to_nearest_real_mse_p95  \
# 0                   3.026798e-09                      0.125351
# 1                   0.000000e+00                      0.030201
# 2                   4.618988e-06                      0.228112
# 3                   6.177299e-03                      0.611593
# 4                   0.000000e+00                      0.000093
# 5                   0.000000e+00                      0.000011
# 6                   6.510883e-02                      1.231704
# 7                   8.846848e-02                      0.716660
# 8                   4.225000e-02                      0.736008
# 9                   3.840708e-02                      2.025235
# 10                  0.000000e+00                      0.004380
# 11                  0.000000e+00                      0.000012
#
#     syn_to_nearest_syn_mse_mean  syn_to_nearest_syn_mse_median  \
# 0                      0.028129                       0.003638
# 1                      0.006898                       0.000772
# 2                      0.031313                       0.003872
# 3                      0.132900                       0.060532
# 4                      0.000069                       0.000049
# 5                      0.000038                       0.000028
# 6                      0.366606                       0.238510
# 7                      0.410574                       0.342877
# 8                      0.271241                       0.199907
# 9                      0.494370                       0.159188
# 10                     0.001064                       0.000433
# 11                     0.000117                       0.000096
#
#     syn_to_nearest_syn_mse_p05  syn_to_nearest_syn_mse_p95  \
# 0                     0.002203                    0.119965
# 1                     0.000401                    0.029795
# 2                     0.002046                    0.149892
# 3                     0.028638                    0.490974
# 4                     0.000028                    0.000158
# 5                     0.000016                    0.000092
# 6                     0.075299                    1.115309
# 7                     0.059344                    1.006055
# 8                     0.066190                    0.721328
# 9                     0.082221                    1.724725
# 10                    0.000209                    0.004027
# 11                    0.000063                    0.000240
#
#     syn_to_nearest_real_mse_mean  syn_to_nearest_real_mse_median  \
# 0                       0.038892                        0.004024
# 1                       0.009734                        0.001468
# 2                       0.040368                        0.004877
# 3                       0.136725                        0.049045
# 4                       0.007006                        0.000586
# 5                       0.000058                        0.000035
# 6                       0.361832                        0.237850
# 7                       0.478832                        0.412968
# 8                       0.277288                        0.212331
# 9                       0.465825                        0.131046
# 10                      0.010125                        0.000853
# 11                      0.000121                        0.000088
#
#     syn_to_nearest_real_mse_p05  syn_to_nearest_real_mse_p95  \
# 0                      0.001577                     0.203081
# 1                      0.000323                     0.045355
# 2                      0.001569                     0.203369
# 3                      0.016723                     0.491595
# 4                      0.000025                     0.031355
# 5                      0.000013                     0.000195
# 6                      0.063469                     1.024983
# 7                      0.053576                     1.083534
# 8                      0.049003                     0.688955
# 9                      0.044681                     1.639471
# 10                     0.000183                     0.045396
# 11                     0.000042                     0.000293
#
#     syn_nn_vs_real_nn_ratio  syn_nearest_real_vs_real_nn_ratio
# 0                  1.133722                           1.567523
# 1                  0.887062                           1.251840
# 2                  0.934145                           1.204303
# 3                  0.923863                           0.950451
# 4                  2.305863                         233.066040
# 5                  9.759271                          14.925739
# 6                  0.966125                           0.953545
# 7                  1.383175                           1.613129
# 8                  1.099506                           1.124016
# 9                  0.805444                           0.758938
# 10                 0.836761                           7.959578
# 11                28.809090                          29.802459
# Average diversity by channel:
#   channel  activity  real_sampled_windows  synthetic_sampled_windows  \
# 0   ACC_x       4.5                1000.0                     1000.0
# 1   ACC_y       4.5                1000.0                     1000.0
# 2   ACC_z       4.5                1000.0                     1000.0
# 3     BVP       4.5                1000.0                     1000.0
# 4     EDA       4.5                1000.0                     1000.0
# 5    TEMP       4.5                1000.0                     1000.0
#
#    real_to_nearest_real_mse_mean  real_to_nearest_real_mse_median  \
# 0                       0.371780                         0.229387
# 1                       0.134301                         0.093564
# 2                       0.253902                         0.154238
# 3                       0.817440                         0.394756
# 4                       0.001368                         0.000382
# 5                       0.000006                         0.000004
#
#    real_to_nearest_real_mse_p05  real_to_nearest_real_mse_p95  \
# 0                  4.386253e-02                      1.126744
# 1                  2.402366e-02                      0.389339
# 2                  2.531972e-02                      0.807119
# 3                  5.201369e-02                      2.865480
# 4                  1.211017e-05                      0.004695
# 5                  1.490116e-07                      0.000015
#
#    syn_to_nearest_syn_mse_mean  syn_to_nearest_syn_mse_median  \
# 0                     0.329084                       0.182432
# 1                     0.154399                       0.112707
# 2                     0.234092                       0.128075
# 3                     0.679440                       0.293922
# 4                     0.001353                       0.000713
# 5                     0.000138                       0.000109
#
#    syn_to_nearest_syn_mse_p05  syn_to_nearest_syn_mse_p95  \
# 0                    0.048530                    1.066040
# 1                    0.028629                    0.405966
# 2                    0.038085                    0.764185
# 3                    0.075311                    2.579333
# 4                    0.000268                    0.004336
# 5                    0.000060                    0.000289
#
#    syn_to_nearest_real_mse_mean  syn_to_nearest_real_mse_median  \
# 0                      0.345082                        0.203449
# 1                      0.186382                        0.142647
# 2                      0.252616                        0.152029
# 3                      0.658637                        0.268694
# 4                      0.003436                        0.000884
# 5                      0.000159                        0.000102
#
#    syn_to_nearest_real_mse_p05  syn_to_nearest_real_mse_p95  \
# 0                     0.038016                     1.087961
# 1                     0.026489                     0.479413
# 2                     0.030510                     0.791015
# 3                     0.042179                     2.486352
# 4                     0.000238                     0.013627
# 5                     0.000038                     0.000390
#
#    syn_nn_vs_real_nn_ratio  syn_nearest_real_vs_real_nn_ratio
# 0                 0.968739                           1.046252
# 1                 1.106973                           1.360753
# 2                 0.988380                           1.077852
# 3                 0.864226                           0.842072
# 4                 1.169185                          30.957096
# 5                22.130726                          26.053486
# Average diversity by activity:
#    activity  real_sampled_windows  synthetic_sampled_windows  \
# 0         1                1000.0                     1000.0
# 1         2                1000.0                     1000.0
# 2         3                1000.0                     1000.0
# 3         4                1000.0                     1000.0
# 4         5                1000.0                     1000.0
# 5         6                1000.0                     1000.0
# 6         7                1000.0                     1000.0
# 7         8                1000.0                     1000.0
#
#    real_to_nearest_real_mse_mean  real_to_nearest_real_mse_median  \
# 0                       0.034999                         0.008560
# 1                       0.256342                         0.149799
# 2                       0.411354                         0.258948
# 3                       0.487257                         0.289881
# 4                       0.261835                         0.151685
# 5                       0.174098                         0.084828
# 6                       0.344354                         0.171550
# 7                       0.134823                         0.047857
#
#    real_to_nearest_real_mse_p05  real_to_nearest_real_mse_p95  \
# 0                      0.001030                      0.165894
# 1                      0.039039                      0.785667
# 2                      0.030378                      1.268915
# 3                      0.051341                      1.517743
# 4                      0.029347                      0.816172
# 5                      0.005366                      0.656088
# 6                      0.032200                      1.162096
# 7                      0.004941                      0.551947
#
#    syn_to_nearest_syn_mse_mean  syn_to_nearest_syn_mse_median  \
# 0                     0.033224                       0.011482
# 1                     0.257329                       0.156835
# 2                     0.290850                       0.135517
# 3                     0.399289                       0.205800
# 4                     0.259892                       0.148826
# 5                     0.172767                       0.080996
# 6                     0.307476                       0.160764
# 7                     0.143846                       0.057057
#
#    syn_to_nearest_syn_mse_p05  syn_to_nearest_syn_mse_p95  \
# 0                    0.005556                    0.131813
# 1                    0.047221                    0.761947
# 2                    0.037787                    1.034820
# 3                    0.060489                    1.351807
# 4                    0.030649                    0.903464
# 5                    0.012971                    0.648708
# 6                    0.046523                    1.035884
# 7                    0.013315                    0.558422
#
#    syn_to_nearest_real_mse_mean  syn_to_nearest_real_mse_median  \
# 0                      0.038797                        0.010006
# 1                      0.265671                        0.165856
# 2                      0.305683                        0.138060
# 3                      0.423699                        0.236472
# 4                      0.270606                        0.159049
# 5                      0.167191                        0.081746
# 6                      0.315973                        0.180254
# 7                      0.140796                        0.052297
#
#    syn_to_nearest_real_mse_p05  syn_to_nearest_real_mse_p95  \
# 0                     0.003372                     0.162492
# 1                     0.035159                     0.747105
# 2                     0.024020                     1.130488
# 3                     0.041962                     1.369349
# 4                     0.021348                     0.878694
# 5                     0.008653                     0.617297
# 6                     0.040822                     1.009008
# 7                     0.007958                     0.563912
#
#    syn_nn_vs_real_nn_ratio  syn_nearest_real_vs_real_nn_ratio
# 0                 2.657321                          42.160983
# 1                 5.650017                           7.035277
# 2                 8.268275                           8.686583
# 3                 5.787796                           5.290332
# 4                 5.303915                           8.238233
# 5                 2.296204                           2.659190
# 6                 3.467019                           4.102216
# 7                 2.873758                           3.610533
# Done.
